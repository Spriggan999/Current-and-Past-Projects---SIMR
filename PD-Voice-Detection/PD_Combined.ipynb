# %%
#Italian
import glob
import numpy as np
import pandas as pd
from six.moves.urllib.parse import quote
import parselmouth
from parselmouth.praat import call
np.random.seed(0)

# %%
def relist():
    sound = parselmouth.Sound(wave_file)
    pitch = sound.to_pitch_ac(very_accurate=False)
    point_process = parselmouth.praat.call([sound, pitch], "To PointProcess (cc)")
    voice_report = parselmouth.praat.call([sound, pitch, point_process],"Voice report", 0, 0, 75, 600, 1.3, 1.6, 0.03, 0.45)
    
    
    
    # Median pitch: 129.212 Hz
    
    i = voice_report.index("Median pitch: ") + len("Median pitch: ")
    j = voice_report.index(" ", i)
    medianpitch = float(voice_report[i:j])
    print(medianpitch)
    
    i = voice_report.index("Mean pitch: ") + len("Mean pitch: ")
    j = voice_report.index(" ", i)
    meanpitch = float(voice_report[i:j])
    print(meanpitch)
    
    i = voice_report.index("Standard deviation: ") + len("Standard deviation: ")
    j = voice_report.index(" ", i)
    standdevpitch = float(voice_report[i:j])
    print(standdevpitch)
    
    i = voice_report.index("Minimum pitch: ") + len("Minimum pitch: ")
    j = voice_report.index(" ", i)
    minpitch = float(voice_report[i:j])
    print(minpitch)
    
    i = voice_report.index("Minimum pitch: ") + len("Minimum pitch: ")
    j = voice_report.index(" ", i)
    maxpitch = float(voice_report[i:j])
    print(maxpitch)
    
    i = voice_report.index("Number of pulses: ") + len("Number of pulses: ")
    j = voice_report.index(" ", i)
    numberpulse = int(voice_report[i:j])
    print(numberpulse)
    
    i = voice_report.index("Number of periods: ") + len("Number of periods: ")
    j = voice_report.index(" ", i)
    numberperiod = int(voice_report[i:j])
    print(numberperiod)
    
    i = voice_report.index("Mean period: ") + len("Mean period: ")
    j = voice_report.index(" ", i)
    meanperiod = float(voice_report[i:j])
    print(meanperiod)
    
    i = voice_report.index("Standard deviation of period: ") + len("Standard deviation of period: ")
    j = voice_report.index(" ", i)
    standdevperiod = float(voice_report[i:j])
    print(standdevperiod)
    
    i = voice_report.index("Fraction of locally unvoiced frames: ") + len("Fraction of locally unvoiced frames: ")
    j = voice_report.index(" ", i)
    fractionluf =voice_report[i:j]
    fractionluf = float(fractionluf.replace("%",""))
    print(fractionluf)

    i = voice_report.index("Number of voice breaks: ") + len("Number of voice breaks: ")
    j = voice_report.index(" ", i)
    numbervoicebreak= int(voice_report[i:j])
    print(numbervoicebreak)
    
    i = voice_report.index("Degree of voice breaks: ") + len("Degree of voice breaks: ")
    j = voice_report.index(" ", i)
    degreevoicebreak =voice_report[i:j]
    degreevoicebreak = float(degreevoicebreak.replace("%",""))
    print(degreevoicebreak)
    
    i = voice_report.index("Jitter (local): ") + len("Jitter (local): ")
    j = voice_report.index("%", i)
    localJitter = float(voice_report[i:j])
    print(localJitter)
    
    i = voice_report.index("Jitter (local, absolute): ") + len("Jitter (local, absolute): ")
    j = voice_report.index(" ", i)
    localabsoluteJitter = float(voice_report[i:j])
    print(localabsoluteJitter)
    
    i = voice_report.index("Jitter (rap): ") + len("Jitter (rap): ")
    j = voice_report.index("%", i)
    rapJitter = float(voice_report[i:j])
    print(rapJitter)
    
    i = voice_report.index("Jitter (ppq5): ") + len("Jitter (ppq5): ")
    j = voice_report.index("%", i)
    ppq5Jitter = float(voice_report[i:j])
    print(ppq5Jitter)
    
    i = voice_report.index("Jitter (ddp): ") + len("Jitter (ddp): ")
    j = voice_report.index("%", i)
    ddpJitter = float(voice_report[i:j])
    print(ddpJitter)
    
    i = voice_report.index("Shimmer (local): ") + len("Shimmer (local): ")
    j = voice_report.index("%", i)
    localShimmer = float(voice_report[i:j])
    print(localShimmer)
    
    i = voice_report.index("Shimmer (local, dB): ") + len("Shimmer (local, dB): ")
    j = voice_report.index(" ", i)
    localdbShimmer = float(voice_report[i:j])
    print(localdbShimmer)
    
    i = voice_report.index("Shimmer (apq3): ") + len("Shimmer (apq3): ")
    j = voice_report.index("%", i)
    apq3Shimmer = float(voice_report[i:j])
    print(apq3Shimmer)
    
    i = voice_report.index("Shimmer (apq5): ") + len("Shimmer (apq5): ")
    j = voice_report.index("%", i)
    aqpq5Shimmer = float(voice_report[i:j])
    print(aqpq5Shimmer)
    
    i = voice_report.index("Shimmer (apq11): ") + len("Shimmer (apq11): ")
    j = voice_report.index("%", i)
    apq11Shimmer = float(voice_report[i:j])
    print(apq11Shimmer)
    
    i = voice_report.index("Shimmer (dda): ") + len("Shimmer (dda): ")
    j = voice_report.index("%", i)
    ddaShimmer = float(voice_report[i:j])
    print(ddaShimmer)
    
    i = voice_report.index("Mean autocorrelation: ") + len("Mean autocorrelation: ")
    j = voice_report.index(" ", i)
    meanac = float(voice_report[i:j])
    print(meanac)
    
    i = voice_report.index("Mean noise-to-harmonics ratio: ") + len("Mean noise-to-harmonics ratio: ")
    j = voice_report.index(" ", i)
    meannth = float(voice_report[i:j])
    print(meannth)
    
    i = voice_report.index("Mean harmonics-to-noise ratio: ") + len("Mean harmonics-to-noise ratio: ")
    j = voice_report.index(" ", i)
    meanhtn = float(voice_report[i:j])
    print(meanhtn)
    
    return medianpitch, meanpitch, standdevpitch, minpitch, maxpitch, numberpulse, numberperiod,meanperiod, standdevperiod, fractionluf, numbervoicebreak, degreevoicebreak, localJitter, localabsoluteJitter, rapJitter, ppq5Jitter, ddpJitter, localShimmer, localdbShimmer, apq3Shimmer, aqpq5Shimmer, apq11Shimmer, ddaShimmer, meanac, meannth, meanhtn

# %%
#parkinson_list, medianpitch_list, meanpitch_list, standdevpitch_list, minpitch_list, maxpitch_list, numberpulse_list, numberperiod_list, meanperiod_list, standdevperiod_list, fractionluf_list, numbervoicebreak_list, degreevoicebreak_list, localJitter_list, localabsoluteJitter_list, rapJitter_list, ppq5Jitter_list, ddpJitter_list, localShimmer_list, localdbShimmer_list, apq3Shimmer_list, aqpq5Shimmer_list, apq11Shimmer_list, ddaShimmer_list, meanac_list, meannth_list, meanhtn_list,
#"Parkinson", "Median_Pitch", "Mean_Pitch", "StandDev_Pitch", "Min_Pitch", "Max_Pitch", "Number_Pulse", "Number_Period", "Mean_Period", "StandDev_Period", "FractionLUF", "Number_VoiceBreak", "Degree_VoiceBreak", "Local_Jitter", "LocAbs_Jitter", "Rap_Jitter", "PPQ5_Jitter", "DDP_Jitter", "Local_Shimmer", "LocAbs_Shimmer", "LocalDB_Shimmer", "APQ3_Shimmer", "APQ5_Shimmer", "APQ11_Shimmer", "DDA_Shimmer", "Mean_AC", "Mean_NTH", "Mean_HTN"
#oof
medianpitch_list = []
meanpitch_list = []
standdevpitch_list = []
minpitch_list = []
maxpitch_list = []
numberpulse_list = []
numberperiod_list = []
meanperiod_list = []
standdevperiod_list = []
fractionluf_list = []
numbervoicebreak_list = []
degreevoicebreak_list = []
localJitter_list = [] #measure
localabsoluteJitter_list = [] #measure
rapJitter_list = [] #measure
ppq5Jitter_list = [] #measure
ddpJitter_list = []
localShimmer_list =  [] #measure
localdbShimmer_list = [] #measure
apq3Shimmer_list = [] #measure
aqpq5Shimmer_list = [] #measure
apq11Shimmer_list =  [] #measure
ddaShimmer_list = []
meanac_list = []
meannth_list = []
meanhtn_list = []
parkinson_list = [] #Parkinson(1) or healthy(0)
file_list = []

property_list = []


print("hi again again")
# Out:
# hi again again

# %%
for wave_file in glob.glob("/Users/yashsaxena/Pdproject/Italian_Parkinson's_Voice_and_speech_copy/28_People_with_Parkinsons_disease/*.wav"):
    sound = parselmouth.Sound(wave_file)
    
    
    
    pitch = sound.to_pitch_ac(very_accurate=False)
    point_process = parselmouth.praat.call([sound, pitch], "To PointProcess (cc)")
    voice_report = parselmouth.praat.call([sound, pitch, point_process],"Voice report", 0, 0, 75, 600, 1.3, 1.6, 0.03, 0.45)
    print(parselmouth.praat.call([sound, pitch, point_process], "Voice report", 0, 0, 75, 600, 1.3, 1.6, 0.03, 0.45))

    
    parkinson_list.append(1) #1 because parkinson file
    file_list.append(wave_file) # make an ID list
    
    (medianpitch, meanpitch, standdevpitch, minpitch, maxpitch, numberpulse, numberperiod,meanperiod, standdevperiod, fractionluf, numbervoicebreak, degreevoicebreak, localJitter, localabsoluteJitter, rapJitter, ppq5Jitter, ddpJitter, localShimmer, localdbShimmer, apq3Shimmer, apq5Shimmer, apq11Shimmer, ddaShimmer, meanac, meannth, meanhtn) = relist()
    
    medianpitch_list.append(medianpitch)
    meanpitch_list.append(meanpitch)
    standdevpitch_list.append(standdevpitch)
    minpitch_list.append(minpitch)
    maxpitch_list.append(maxpitch)
    numberpulse_list.append(numberpulse)
    numberperiod_list.append(numberperiod)
    meanperiod_list.append(meanperiod)
    standdevperiod_list.append(standdevperiod)
    fractionluf_list.append(fractionluf)
    numbervoicebreak_list.append(numbervoicebreak)
    degreevoicebreak_list.append(degreevoicebreak)
    localJitter_list.append(localJitter)
    localabsoluteJitter_list.append(localabsoluteJitter)
    rapJitter_list.append(rapJitter)
    ppq5Jitter_list.append(ppq5Jitter)
    ddpJitter_list.append(ddpJitter)
    localShimmer_list.append(localShimmer)
    localdbShimmer_list.append(localdbShimmer)
    apq3Shimmer_list.append(apq3Shimmer)
    aqpq5Shimmer_list.append(apq5Shimmer)
    apq11Shimmer_list.append(apq11Shimmer)
    ddaShimmer_list.append(ddaShimmer)
    meanac_list.append(meanac)
    meannth_list.append(meannth)
    meanhtn_list.append(meanhtn)
    


    print('after loop 1')
    print(parkinson_list)

for wave_file in glob.glob("/Users/yashsaxena/Pdproject/Italian_Parkinson's_Voice_and_speech_copy/37_Healthy_People/15_Young_Healthy_Control/*.wav"):
    sound = parselmouth.Sound(wave_file)
    
    
    
    pitch = sound.to_pitch_ac(very_accurate=False)
    point_process = parselmouth.praat.call([sound, pitch], "To PointProcess (cc)")
    voice_report = parselmouth.praat.call([sound, pitch, point_process],"Voice report", 0, 0, 75, 600, 1.3, 1.6, 0.03, 0.45)
    print(parselmouth.praat.call([sound, pitch, point_process], "Voice report", 0, 0, 75, 600, 1.3, 1.6, 0.03, 0.45))
    

    
    parkinson_list.append(0) #0 because no parkinson file
    file_list.append(wave_file) # make an ID list
    
    (medianpitch, meanpitch, standdevpitch, minpitch, maxpitch, numberpulse, numberperiod,meanperiod, standdevperiod, fractionluf, numbervoicebreak, degreevoicebreak, localJitter, localabsoluteJitter, rapJitter, ppq5Jitter, ddpJitter, localShimmer, localdbShimmer, apq3Shimmer, apq5Shimmer, apq11Shimmer, ddaShimmer, meanac, meannth, meanhtn) = relist()
    
    medianpitch_list.append(medianpitch)
    meanpitch_list.append(meanpitch)
    standdevpitch_list.append(standdevpitch)
    minpitch_list.append(minpitch)
    maxpitch_list.append(maxpitch)
    numberpulse_list.append(numberpulse)
    numberperiod_list.append(numberperiod)
    meanperiod_list.append(meanperiod)
    standdevperiod_list.append(standdevperiod)
    fractionluf_list.append(fractionluf)
    numbervoicebreak_list.append(numbervoicebreak)
    degreevoicebreak_list.append(degreevoicebreak)
    localJitter_list.append(localJitter)
    localabsoluteJitter_list.append(localabsoluteJitter)
    rapJitter_list.append(rapJitter)
    ppq5Jitter_list.append(ppq5Jitter)
    ddpJitter_list.append(ddpJitter)
    localShimmer_list.append(localShimmer)
    localdbShimmer_list.append(localdbShimmer)
    apq3Shimmer_list.append(apq3Shimmer)
    aqpq5Shimmer_list.append(apq5Shimmer)
    apq11Shimmer_list.append(apq11Shimmer)
    ddaShimmer_list.append(ddaShimmer)
    meanac_list.append(meanac)
    meannth_list.append(meannth)
    meanhtn_list.append(meanhtn)
    


    print('after loop 2')
    print(parkinson_list)

for wave_file in glob.glob("/Users/yashsaxena/Pdproject/Italian_Parkinson's_Voice_and_speech_copy/37_Healthy_People/22_Elderly_Healthy_Control/*.wav"):
    sound = parselmouth.Sound(wave_file)
    
    
    
    pitch = sound.to_pitch_ac(very_accurate=False)
    point_process = parselmouth.praat.call([sound, pitch], "To PointProcess (cc)")
    voice_report = parselmouth.praat.call([sound, pitch, point_process],"Voice report", 0, 0, 75, 600, 1.3, 1.6, 0.03, 0.45)
    print(parselmouth.praat.call([sound, pitch, point_process], "Voice report", 0, 0, 75, 600, 1.3, 1.6, 0.03, 0.45))
    

    
    parkinson_list.append(0) #0 because no parkinson file
    file_list.append(wave_file) # make an ID list
    
    (medianpitch, meanpitch, standdevpitch, minpitch, maxpitch, numberpulse, numberperiod,meanperiod, standdevperiod, fractionluf, numbervoicebreak, degreevoicebreak, localJitter, localabsoluteJitter, rapJitter, ppq5Jitter, ddpJitter, localShimmer, localdbShimmer, apq3Shimmer, apq5Shimmer, apq11Shimmer, ddaShimmer, meanac, meannth, meanhtn) = relist()
    
    medianpitch_list.append(medianpitch)
    meanpitch_list.append(meanpitch)
    standdevpitch_list.append(standdevpitch)
    minpitch_list.append(minpitch)
    maxpitch_list.append(maxpitch)
    numberpulse_list.append(numberpulse)
    numberperiod_list.append(numberperiod)
    meanperiod_list.append(meanperiod)
    standdevperiod_list.append(standdevperiod)
    fractionluf_list.append(fractionluf)
    numbervoicebreak_list.append(numbervoicebreak)
    degreevoicebreak_list.append(degreevoicebreak)
    localJitter_list.append(localJitter)
    localabsoluteJitter_list.append(localabsoluteJitter)
    rapJitter_list.append(rapJitter)
    ppq5Jitter_list.append(ppq5Jitter)
    ddpJitter_list.append(ddpJitter)
    localShimmer_list.append(localShimmer)
    localdbShimmer_list.append(localdbShimmer)
    apq3Shimmer_list.append(apq3Shimmer)
    aqpq5Shimmer_list.append(apq5Shimmer)
    apq11Shimmer_list.append(apq11Shimmer)
    ddaShimmer_list.append(ddaShimmer)
    meanac_list.append(meanac)
    meannth_list.append(meannth)
    meanhtn_list.append(meanhtn)
    


    print('after loop 3')
    print(parkinson_list)
print("hi againX4")

pred = pd.DataFrame(np.column_stack([parkinson_list, medianpitch_list, meanpitch_list, standdevpitch_list, minpitch_list, maxpitch_list, numberpulse_list, numberperiod_list, meanperiod_list, standdevperiod_list, fractionluf_list, numbervoicebreak_list, degreevoicebreak_list, localJitter_list, localabsoluteJitter_list, rapJitter_list, ppq5Jitter_list, ddpJitter_list, localShimmer_list, localdbShimmer_list, apq3Shimmer_list, aqpq5Shimmer_list, apq11Shimmer_list, ddaShimmer_list, meanac_list, meannth_list, meanhtn_list]),
                               columns=["Parkinson", "Median_Pitch", "Mean_Pitch", "StandDev_Pitch", "Min_Pitch", "Max_Pitch", "Number_Pulse", "Number_Period", "Mean_Period", "StandDev_Period", "FractionLUF", "Number_VoiceBreak", "Degree_VoiceBreak", "Local_Jitter", "LocAbs_Jitter", "Rap_Jitter", "PPQ5_Jitter", "DDP_Jitter", "Local_Shimmer", "LocalDB_Shimmer", "APQ3_Shimmer", "APQ5_Shimmer", "APQ11_Shimmer", "DDA_Shimmer", "Mean_AC", "Mean_NTH", "Mean_HTN"])  #add these lists to pandas in the right order
print(pred)
pred.to_csv("processed_results.csv", index=False) # Write out the updated dataset
np.any(np.isnan(pred))
np.all(np.isfinite(pred))

parkinsonitalian = pd.read_csv("processed_results.csv") #Loading CSV dataset

predictors=["Median_Pitch", "Mean_Pitch", "StandDev_Pitch", "Min_Pitch", "Max_Pitch", "Number_Pulse", "Number_Period", "Mean_Period", "StandDev_Period", "FractionLUF", "Number_VoiceBreak", "Degree_VoiceBreak", "Local_Jitter", "LocAbs_Jitter", "Rap_Jitter", "PPQ5_Jitter", "DDP_Jitter", "Local_Shimmer", "LocalDB_Shimmer", "APQ3_Shimmer", "APQ5_Shimmer", "APQ11_Shimmer", "DDA_Shimmer", "Mean_AC", "Mean_NTH", "Mean_HTN"] #Listing predictors

for col in predictors: # Loop through all columns in predictors
    if parkinsonitalian[col].dtype == 'object':  # check if column's type is object (text)
        parkinsonitalian[col] = pd.Categorical(parkinsonitalian[col]).codes  # convert text to numerical

        
#Turkish
parkinsonturkish = pd.read_csv("/Users/yashsaxena/Pdproject/manypdtypessample(engl)_copy/train_data_final_one.csv")
display(parkinsonturkish) 


predictors=["Median_Pitch", "Mean_Pitch", "StandDev_Pitch", "Min_Pitch", "Max_Pitch", "Number_Pulse", "Number_Period", "Mean_Period", "StandDev_Period", "FractionLUF", "Number_VoiceBreak", "Degree_VoiceBreak", "Local_Jitter", "LocAbs_Jitter", "Rap_Jitter", "PPQ5_Jitter", "DDP_Jitter", "Local_Shimmer", "LocalDB_Shimmer", "APQ3_Shimmer", "APQ5_Shimmer", "APQ11_Shimmer", "DDA_Shimmer", "Mean_AC", "Mean_NTH", "Mean_HTN"]

for col in predictors: # Loop through all columns in predictors
    if parkinsonturkish[col].dtype == 'object':  # check if column's type is object (text)
        parkinsonturkish[col] = pd.Categorical(parkinsonturkish[col]).codes  # convert text to numerical
 #both
parkinsoncombined = pd.concat((parkinsonitalian, parkinsonturkish))
parkinsoncombined.reset_index(inplace=True, drop=True)
display(parkinsoncombined)

predictors=["Median_Pitch", "Mean_Pitch", "StandDev_Pitch", "Min_Pitch", "Max_Pitch", "Number_Pulse", "Number_Period", "Mean_Period", "StandDev_Period", "FractionLUF", "Number_VoiceBreak", "Degree_VoiceBreak", "Local_Jitter", "LocAbs_Jitter", "Rap_Jitter", "PPQ5_Jitter", "DDP_Jitter", "Local_Shimmer", "LocalDB_Shimmer", "APQ3_Shimmer", "APQ5_Shimmer", "APQ11_Shimmer", "DDA_Shimmer", "Mean_AC", "Mean_NTH", "Mean_HTN"]

for col in predictors: # Loop through all columns in predictors
    if parkinsoncombined[col].dtype == 'object':  # check if column's type is object (text)
        parkinsoncombined[col] = pd.Categorical(parkinsoncombined[col]).codes  # convert text to numerical

# %%
accuracyitalian = []
f1italian = []
precisionitalian = []
recallitalian = []
tpitalian = []
fpitalian = []
tnitalian = []
fnitalian = []


accuracyturkish = []
f1turkish = []
precisionturkish = []
recallturkish = []
tpturkish = []
fpturkish = []
tnturkish = []
fnturkish = []

accuracycombined = []
f1combined = []
precisioncombined = []
recallcombined = []
tpcombined = []
fpcombined = []
tncombined = []
fncombined = []

for i in range(100):
    
    parkinsonitalianshuffle = parkinsonitalian
    
    parkinsonitalianshuffle = parkinsonitalian.sample(frac = 1, random_state = i).reset_index(drop=True)
    from sklearn.model_selection import train_test_split
    
    X_trainitalian, X_testitalian, y_trainitalian, y_testitalian = train_test_split(parkinsonitalianshuffle[predictors], parkinsonitalianshuffle['Parkinson'], test_size=0.2, random_state=1)        
    
    from sklearn.ensemble import GradientBoostingClassifier
    import sklearn.metrics
    nn = GradientBoostingClassifier()
    nn.fit(X_trainitalian, y_trainitalian)
    test_scoreitalian = nn.score(X_testitalian, y_testitalian)
    yhat_testitalian = nn.predict(X_testitalian)
    f1_scoreitalian = sklearn.metrics.f1_score(y_testitalian,yhat_testitalian, average = 'binary')
    precision_italian = sklearn.metrics.precision_score(y_testitalian,yhat_testitalian, average = 'binary')
    recall_italian = sklearn.metrics.recall_score(y_testitalian,yhat_testitalian, average = 'binary')
    confusionmatrix_italian = sklearn.metrics.confusion_matrix(y_testitalian,yhat_testitalian)
    print ('test accuracy = ', test_scoreitalian)
    print('f1 score =', f1_scoreitalian)
    print('precision score =', precision_italian)
    print('recall score=', recall_italian)
    print('confusion matrix = ', confusionmatrix_italian)
    accuracyitalian.append(test_scoreitalian)
    f1italian.append(f1_scoreitalian)
    precisionitalian.append(precision_italian)
    recallitalian.append(recall_italian)
    tn_italian, fp_italian, fn_italian, tp_italian = confusionmatrix_italian.ravel()
    tnitalian.append(tn_italian)
    fpitalian.append(fp_italian)
    fnitalian.append(fn_italian)
    tpitalian.append(tp_italian)
    
    
    parkinsonturkishshuffle = parkinsonturkish
    parkinsonturkishshuffle = parkinsonturkish.sample(frac = 1, random_state = i).reset_index(drop=True)
    X_trainturkish, X_testturkish, y_trainturkish, y_testturkish = train_test_split(parkinsonturkishshuffle[predictors], parkinsonturkishshuffle['Parkinson'], test_size=0.2, random_state=1)        

    nn = GradientBoostingClassifier()
    nn.fit(X_trainturkish, y_trainturkish)
    test_scoreturkish = nn.score(X_testturkish, y_testturkish)
    yhat_testturkish = nn.predict(X_testturkish)
    f1_scoreturkish = sklearn.metrics.f1_score(y_testturkish,yhat_testturkish, average = 'binary')
    precision_turkish = sklearn.metrics.precision_score(y_testturkish,yhat_testturkish, average = 'binary')
    recall_turkish = sklearn.metrics.recall_score(y_testturkish,yhat_testturkish, average = 'binary')
    confusionmatrix_turkish = sklearn.metrics.confusion_matrix(y_testturkish,yhat_testturkish)
    print ('test accuracy = ', test_scoreturkish)
    print('f1 score =', f1_scoreturkish)
    print('precision score =', precision_turkish)
    print('recall score=', recall_turkish)
    print('confusion matrix = ', confusionmatrix_turkish)
    accuracyturkish.append(test_scoreturkish)
    f1turkish.append(f1_scoreturkish)
    precisionturkish.append(precision_turkish)
    recallturkish.append(recall_turkish)
    tn_turkish, fp_turkish, fn_turkish, tp_turkish = confusionmatrix_turkish.ravel()
    tnturkish.append(tn_turkish)
    fpturkish.append(fp_turkish)
    fnturkish.append(fn_turkish)
    tpturkish.append(tp_turkish)
    
    
    parkinsoncombinedshuffle = parkinsoncombined
    parkinsoncombinedshuffle = parkinsoncombined.sample(frac = 1, random_state = i).reset_index(drop=True)
    X_traincombined, X_testcombined, y_traincombined, y_testcombined = train_test_split(parkinsoncombinedshuffle[predictors], parkinsoncombinedshuffle['Parkinson'], test_size=0.2, random_state=1)        

    nn = GradientBoostingClassifier()
    nn.fit(X_traincombined, y_traincombined)
    test_scorecombined = nn.score(X_testcombined, y_testcombined)
    yhat_testcombined = nn.predict(X_testcombined)
    f1_scorecombined = sklearn.metrics.f1_score(y_testcombined,yhat_testcombined, average = 'binary')
    precision_combined = sklearn.metrics.precision_score(y_testcombined,yhat_testcombined, average = 'binary')
    recall_combined = sklearn.metrics.recall_score(y_testcombined,yhat_testcombined, average = 'binary')
    confusionmatrix_combined = sklearn.metrics.confusion_matrix(y_testcombined,yhat_testcombined)
    print ('test accuracy = ', test_scorecombined)
    print('f1 score =', f1_scorecombined)
    print('precision score =', precision_combined)
    print('recall score=', recall_combined)
    print('confusion matrix = ', confusionmatrix_combined)
    accuracycombined.append(test_scorecombined)
    f1combined.append(f1_scorecombined)
    precisioncombined.append(precision_combined)
    recallcombined.append(recall_combined)

    tn_combined, fp_combined, fn_combined, tp_combined = confusionmatrix_combined.ravel()
    tncombined.append(tn_combined)
    fpcombined.append(fp_combined)
    fncombined.append(fn_combined)
    tpcombined.append(tp_combined)

# %%
statdf = pd.DataFrame(np.column_stack([accuracyitalian, f1italian, precisionitalian, recallitalian,tnitalian,fpitalian,fnitalian,tpitalian, accuracyturkish, f1turkish, precisionturkish, recallturkish, tnturkish,fpturkish,fnturkish,tpturkish, accuracycombined, f1combined, precisioncombined, recallcombined, tncombined,fpcombined,fncombined,tpcombined]),
                               columns=["Italian_Accuracy", "Italian_F1", "Italian_Precision", "Italian_Recall","Italian_TrueNegative", "Italian_FalsePositive","Italian_FalseNegative","Italian_TruePositive","Turkish_Accuracy", "Turkish_F1", "Turkish_Precision", "Turkish_Recall","Turkish_TrueNegative","Turkish_FalsePositive","Turkish_FalseNegative","Turkish_TruePositive","Combined_Accuracy", "Combined_F1", "Combined_Precision", "Combined_Recall", "Combined_TrueNegative", "Combined_FalsePositive","Combined_FalseNegative","Combined_TruePositive"])  #add these lists to pandas in the right order
display(statdf)

# %%
from IPython.display import HTML
import base64

def create_download_link( df, title = "Download CSV file", filename = "parkinsonstatisticdata_recoveryb.csv"):  
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

create_download_link(statdf)
